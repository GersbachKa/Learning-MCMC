# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
print("Gaussian to model:")
data = np.loadtxt("gaussian.txt")
plt.plot(data)
plt.show()
plt.hist(data,100)
plt.show()
# Out:
# Gaussian to model:

# %%
print("Projected values")
out = np.loadtxt("mcmc_out.txt")
mu = out[:,0].transpose()
sigma = out[:,1].transpose()


burnLength = (int)(0.25*len(mu))

print("Value of Mu")
plt.plot(mu)
plt.show()
plt.hist(mu[burnLength:],100)
plt.show()

print("Value of Sigma")
plt.plot(sigma)
plt.show()
plt.hist(sigma[burnLength:],100)
plt.show()
# Out:
# Projected values
# Value of Mu
# Value of Sigma
